# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image

# %%
np.random.seed(42)
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv(r"C:\Users\srija\Assignment\AI_ML_GC\aiml-general-championship\KCDH2024_Training_GroundTruth.csv")

# %%
df
# Out:
#               image  MEL  NV  BCC  AKIEC  BKL  DF  VASC
# 0      ISIC_0024306    0   1    0      0    0   0     0
# 1      ISIC_0024307    0   1    0      0    0   0     0
# 2      ISIC_0024308    0   1    0      0    0   0     0
# 3      ISIC_0024309    0   1    0      0    0   0     0
# 4      ISIC_0024310    1   0    0      0    0   0     0
# ...             ...  ...  ..  ...    ...  ...  ..   ...
# 10010  ISIC_0034316    1   0    0      0    0   0     0
# 10011  ISIC_0034317    1   0    0      0    0   0     0
# 10012  ISIC_0034318    0   0    0      0    1   0     0
# 10013  ISIC_0034319    0   1    0      0    0   0     0
# 10014  ISIC_0034320    0   1    0      0    0   0     0
#
# [10015 rows x 8 columns]

# %%
imageID =  df['image']

# %%
imageID
# Out:
# 0        ISIC_0024306
# 1        ISIC_0024307
# 2        ISIC_0024308
# 3        ISIC_0024309
# 4        ISIC_0024310
#              ...
# 10010    ISIC_0034316
# 10011    ISIC_0034317
# 10012    ISIC_0034318
# 10013    ISIC_0034319
# 10014    ISIC_0034320
# Name: image, Length: 10015, dtype: object

# %%
image_path = []

# %%
base_path = r"C:\Users\srija\Assignment\AI_ML_GC\aiml-general-championship\KCDH2024_Training_Input_10K\KCDH2024_Training_Input_10K"
true_path = os.path.join(base_path,imageID[0]+".jpg")
true_path
# Out:
# 'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024306.jpg'

# %%
img = Image.open(true_path)

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>

# %%
for elem in imageID:
    path = os.path.join(base_path,elem +".jpg")
    image_path.append(path)

# %%
image_path
# Out:
# ['C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024306.jpg',
#  'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024307.jpg',
#  'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024308.jpg',
#  'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024309.jpg',
#  'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024310.jpg',
#  'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0024311.jpg',
# ...

# %%
len(image_path)
# Out:
# 10015

# %%
len(imageID)
# Out:
# 10015

# %%
image_path[10014]
# Out:
# 'C:\\Users\\srija\\Assignment\\AI_ML_GC\\aiml-general-championship\\KCDH2024_Training_Input_10K\\KCDH2024_Training_Input_10K\\ISIC_0034320.jpg'

# %%
imageID[10014]
# Out:
# 'ISIC_0034320'

# %%
df1  = pd.DataFrame(image_path, columns =['path'])
# new_column_series = pd.Series(image_path)


# df = pd.concat([df, new_column_series], names=['Path'],axis=1)

# %%
df1
# Out:
#                                                     path
# 0      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 1      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 2      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 3      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 4      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# ...                                                  ...
# 10010  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 10011  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 10012  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 10013  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 10014  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
#
# [10015 rows x 1 columns]

# %%
newdf = pd.concat([df,df1],axis=1)

# %%
newdf
# Out:
#               image  MEL  NV  BCC  AKIEC  BKL  DF  VASC  \
# 0      ISIC_0024306    0   1    0      0    0   0     0
# 1      ISIC_0024307    0   1    0      0    0   0     0
# 2      ISIC_0024308    0   1    0      0    0   0     0
# 3      ISIC_0024309    0   1    0      0    0   0     0
# 4      ISIC_0024310    1   0    0      0    0   0     0
# ...             ...  ...  ..  ...    ...  ...  ..   ...
# 10010  ISIC_0034316    1   0    0      0    0   0     0
# 10011  ISIC_0034317    1   0    0      0    0   0     0
# 10012  ISIC_0034318    0   0    0      0    1   0     0
# 10013  ISIC_0034319    0   1    0      0    0   0     0
# 10014  ISIC_0034320    0   1    0      0    0   0     0
#
#                                                     path
# 0      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 1      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 2      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 3      C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# ...

# %%
for i in range(0,len(newdf['path'])):
    try:
        imag1 = Image.open(newdf['path'][i])
    except:
        newdf.drop(i,axis=0,inplace=True)

len(newdf)
# Out:
# 9600

# %%
selected_columns1 = ['MEL', 'NV', 'BCC','AKIEC','BKL','DF','VASC']  # List of columns you want to select
Y_df1 = newdf.loc[:, selected_columns1]

# %%
len(Y_df1)
# Out:
# 9600

# %%
list_of_counts = [0,0,0,0,0,0,0] 
## lst[0] =count of MEL
## lst[1] =count of NV and so on

list_of_counts[6]
# Out:
# 0

# %%
for i in range(0,len(newdf['image'])):
    if(newdf['MEL'][i]==1):
        list_of_counts[0]+=1;
    if(newdf['NV'][i]==1):
        list_of_counts[1]+=1;
    if(newdf['BCC'][i]==1):
        list_of_counts[2]+=1;
    if(newdf['AKIEC'][i]==1):
        list_of_counts[3]+=1;
    if(newdf['BKL'][i]==1):
        list_of_counts[4]+=1;
    if(newdf['DF'][i]==1):
        list_of_counts[5]+=1;
    if(newdf['VASC'][i]==1):
        list_of_counts[6]+=1;

# %%
list_of_counts
# Out:
# [1015, 6457, 495, 327, 1055, 113, 138]

# %%
df_0 = newdf[newdf['MEL'] == 1]
df_1 = newdf[newdf['NV'] == 1]
df_2 = newdf[newdf['BCC'] == 1]
df_3 = newdf[newdf['AKIEC'] == 1]
df_4 = newdf[newdf['BKL'] == 1]
df_5 = newdf[newdf['DF'] == 1]
df_6 = newdf[newdf['VASC'] == 1]

# %%
len(df_0)
# Out:
# 1015

# %%
len(df_1)
# Out:
# 6457

# %%
from sklearn.utils import resample
n_samples=7000
df_0_balanced = resample(df_0, replace=True, n_samples=n_samples, random_state=42) 
df_1_balanced = resample(df_1, replace=True, n_samples=n_samples, random_state=42) 
df_2_balanced = resample(df_2, replace=True, n_samples=n_samples, random_state=42)
df_3_balanced = resample(df_3, replace=True, n_samples=n_samples, random_state=42)
df_4_balanced = resample(df_4, replace=True, n_samples=n_samples, random_state=42)
df_5_balanced = resample(df_5, replace=True, n_samples=n_samples, random_state=42)
df_6_balanced = resample(df_6, replace=True, n_samples=n_samples, random_state=42)

# %%
df_0_balanced
# Out:
#              image  MEL  NV  BCC  AKIEC  BKL  DF  VASC  \
# 1144  ISIC_0025450    1   0    0      0    0   0     0
# 5010  ISIC_0029316    1   0    0      0    0   0     0
# 8920  ISIC_0033226    1   0    0      0    0   0     0
# 3046  ISIC_0027352    1   0    0      0    0   0     0
# 1194  ISIC_0025500    1   0    0      0    0   0     0
# ...            ...  ...  ..  ...    ...  ...  ..   ...
# 4136  ISIC_0028442    1   0    0      0    0   0     0
# 9118  ISIC_0033424    1   0    0      0    0   0     0
# 1218  ISIC_0025524    1   0    0      0    0   0     0
# 2298  ISIC_0026604    1   0    0      0    0   0     0
# 9099  ISIC_0033405    1   0    0      0    0   0     0
#
#                                                    path
# 1144  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 5010  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 8920  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# 3046  C:\Users\srija\Assignment\AI_ML_GC\aiml-genera...
# ...

# %%
df_balanced = pd.concat([df_0_balanced, df_1_balanced, 
                              df_2_balanced, df_3_balanced, 
                              df_4_balanced, df_5_balanced, df_6_balanced])

# %%
len(df_balanced)
# Out:
# 49000

# %%
selected_columns = ['MEL', 'NV', 'BCC','AKIEC','BKL','DF','VASC']  # List of columns you want to select
Y_df = df_balanced.loc[:, selected_columns]

# %%
Y_df
# Out:
#       MEL  NV  BCC  AKIEC  BKL  DF  VASC
# 1144    1   0    0      0    0   0     0
# 5010    1   0    0      0    0   0     0
# 8920    1   0    0      0    0   0     0
# 3046    1   0    0      0    0   0     0
# 1194    1   0    0      0    0   0     0
# ...   ...  ..  ...    ...  ...  ..   ...
# 7751    0   0    0      0    0   0     1
# 1015    0   0    0      0    0   0     1
# 3840    0   0    0      0    0   0     1
# 5764    0   0    0      0    0   0     1
# 2043    0   0    0      0    0   0     1
#
# [49000 rows x 7 columns]

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import numpy as np
class TrainData(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = Image.open(img_path).convert("RGB")

        if self.transform:
            img = self.transform(img)

        label = self.labels[idx]

        return img, label



class ValData(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = Image.open(img_path).convert("RGB")

        if self.transform:
            img = self.transform(img)

        label = self.labels[idx]

        return img, label

# %%
def compute_img_mean_std(image_paths):
    """
        computing the mean and std of three channel on the whole dataset,
        first we should normalize the image from 0-255 to 0-1
    """

    img_h, img_w = 224, 224
    imgs = []
    means, stdevs = [], []

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        imgs.append(img)

    imgs = np.stack(imgs, axis=3)
    print(imgs.shape)

    imgs = imgs.astype(np.float32) / 255.

    for i in range(3):
        pixels = imgs[:, :, i, :].ravel()  # resize to one row
        means.append(np.mean(pixels))
        stdevs.append(np.std(pixels))

    means.reverse()  # BGR --> RGB
    stdevs.reverse()

    print("normMean = {}".format(means))
    print("normStd = {}".format(stdevs))
    return means,stdevs

# %%
import os, cv2,itertools
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
compute_img_mean_std(df_balanced['path'].tolist())
# Out:
# 100%|██████████| 49000/49000 [11:58<00:00, 68.16it/s]
# (224, 224, 3, 49000)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[43], line 5
#       3 import numpy as np
#       4 from tqdm import tqdm
# ----> 5 compute_img_mean_std(df_balanced['path'].tolist())
#
# Cell In[40], line 19, in compute_img_mean_std(image_paths)
#      16 imgs = np.stack(imgs, axis=3)
#      17 print(imgs.shape)
# ---> 19 imgs = imgs.astype(np.float32) / 255.
#      21 for i in range(3):
#      22     pixels = imgs[:, :, i, :].ravel()  # resize to one row
#
# MemoryError: Unable to allocate 27.5 GiB for an array with shape (224, 224, 3, 49000) and data type float32

# %%
normMean = [0.76696384, 0.54525656, 0.56884694]
normStd = [0.13945772, 0.15192385, 0.16916788]
normMean1 = [0.760109, 0.5553756, 0.5792942]
normStd1 = [0.14573097, 0.16013189, 0.17759693]
train_transform = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),
                                      transforms.RandomRotation(20),
                                      transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1),
                                        transforms.ToTensor(), 
                                      transforms.Normalize(normMean, normStd)])

val_transform = transforms.Compose([transforms.Resize((224,224)), 
                                    transforms.ToTensor(),
                                    transforms.Normalize(normMean1, normStd1)])

# %%
image_paths = df_balanced['path']
image_paths = image_paths.tolist()
# Assuming labels are already one-hot encoded, for example, 3 classes
labels = np.array(Y_df)

labels = torch.tensor(labels)

from sklearn.model_selection import train_test_split

train_paths, val_paths, train_labels, val_labels = train_test_split(image_paths, labels, test_size=0.15, random_state=42)

batch_size = 16
# Create training dataset and dataloader
train_dataset = TrainData(train_paths, train_labels, transform=train_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Create validation dataset and dataloader
val_dataset = TrainData(val_paths, val_labels, transform= val_transform)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
print(len(val_dataset))
# Out:
# 7350

# %%
path = r"C:\Users\srija\Assignment\AI_ML_GC\aiml-general-championship\KCDH2024_Test_Input\KCDH2024_Test_Input\\"
dir_list = os.listdir(path)
list_test_id = []
list_test_path = []
for elem in dir_list:
  if(elem=="LICENSE.txt"):
      continue
  else:
      list_test_path.append(path+elem)
      list_test_id.append(elem[0:-4])

# %%
print(list_test_path[0])
# Out:
# C:\Users\srija\Assignment\AI_ML_GC\aiml-general-championship\KCDH2024_Test_Input\KCDH2024_Test_Input\\ISIC_0034524.jpg

# %%
img = Image.open(list_test_path[0])
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>

# %%
len(list_test_path)
# Out:
# 1512

# %%
class TestDataset(Dataset):
    def __init__(self, image_paths, transform=None):
        self.image_paths = image_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# Set your test data directory

test_image_paths = list_test_path  # List of test image directory paths

# Define transformations for test data
test_transform =  transforms.Compose([transforms.Resize((224,224)), 
                                    transforms.ToTensor(),
                                    transforms.Normalize(norm_mean, norm_std)])

# Create test dataset and dataloader
test_dataset = TestDataset(test_image_paths, transform=test_transform)
test_dataloader = DataLoader(test_dataset, batch_size=2, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 23
#      18 test_image_paths = list_test_path  # List of test image directory paths
#      20 # Define transformations for test data
#      21 test_transform =  transforms.Compose([transforms.Resize((224,224)),
#      22                                     transforms.ToTensor(),
# ---> 23                                     transforms.Normalize(norm_mean, norm_std)])
#      25 # Create test dataset and dataloader
#      26 test_dataset = TestDataset(test_image_paths, transform=test_transform)
#
# NameError: name 'norm_mean' is not defined

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim

# %%
import torch
import torchvision.models as models

# Load pretrained ResNet model
model = models.densenet121(pretrained=True)

# Print the model architecture to see the names of all layers
print(model)

# Get the name of the last layer
last_layer_name = None
for name, module in model.named_modules():
    if len(list(module.children())) == 0:  # If the module has no children, it's a leaf module (layer)
        last_layer_name = name

# Print the name of the last layer
print("Name of the last layer:", last_layer_name)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
# ...

# %%
import torch.nn as nn
import torch.nn.functional as F

# Freeze initial layers
# for param in model.parameters():
#     param.requires_grad = False
# num_classes =7
# Modify the last fully connected layer for your classification task
# num_ftrs = model.fc.in_features
# model.fc1 = nn.Linear(512, 256)
# model.fc2 = nn.Linear(256, 128)
# model.fc3 = nn.Linear(128, 64)
# model.fc4 = nn.Linear(64, 512)
# model.fc5 = nn.Linear(512, 256)
# model.fc6 = nn.Linear(256, 128)
# model.fc7 = nn.Linear(128, 64)
# model.fc8 = nn.Linear(64, 32)
# model.fc9 = nn.Linear(32, 16)
# model.fc10 = nn.Linear(16, 7)


import torch.nn.functional as F
import torch.nn as nn
import torchvision.models as models

# class DenseNetModel(nn.Module):
#     def __init__(self, num_classes):
#         super(DenseNetModel, self).__init__()
#         self.densenet = models.densenet121(pretrained=True)
#         # for param in self.densenet.parameters():
#         #     param.requires_grad = False
#         # for param in self.densenet.classifier.parameters():
#         #     param.requires_grad = True
#         # num_ftrs = self.resnet.fc.in_features
#         self.fc0 = nn.Linear(1024, 512)
#         self.fc1 = nn.Linear(512, 256)
#         self.dropout1 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc2 = nn.Linear(256, 128)
#         self.dropout2 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc3 = nn.Linear(128, 64)
#         self.dropout3 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc4 = nn.Linear(64, 512)
#         self.dropout4 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc5 = nn.Linear(512, 256)
#         self.dropout5 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc6 = nn.Linear(256, 128)
#         self.dropout6 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc7 = nn.Linear(128, 64)
#         self.dropout7 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc8 = nn.Linear(64, 32)
#         self.dropout8 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc9 = nn.Linear(32, 16)
#         self.dropout9 = nn.Dropout(p=0.2)  # Changed dropout rate to 0.2
#         self.fc10 = nn.Linear(16, 7)

#     def forward(self, x):
#         print('started')
#         x = self.densenet(x)
#         print('densetnet passed')
#         x = self.fc0(x)
#         x = F.relu(self.fc1(x))
#         x = self.dropout1(x)
#         x = F.relu(self.fc2(x))
#         x = self.dropout2(x)
#         x = F.relu(self.fc3(x))
#         x = self.dropout3(x)
#         x = F.relu(self.fc4(x))
#         x = self.dropout4(x)
#         x = F.relu(self.fc5(x))
#         x = self.dropout5(x)
#         x = F.relu(self.fc6(x))
#         x = self.dropout6(x)
#         x = F.relu(self.fc7(x))
#         x = self.dropout7(x)
#         x = F.relu(self.fc8(x))
#         x = self.dropout8(x)
#         x = F.relu(self.fc9(x))
#         x = self.dropout9(x)
#         x = self.fc10(x)
#         return x

densenet = models.densenet121(pretrained=True)

# Modify the architecture
num_ftrs = densenet.classifier.in_features
print(num_ftrs)
densenet.classifier = nn.Sequential(
    nn.Linear(num_ftrs, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(64, 7)  # Assuming num_classes is the number of output classes
)
# Out:
# c:\Users\srija\anaconda3\envs\aigc\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\srija\anaconda3\envs\aigc\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 1024

# %%
model = models.densenet121(pretrained=True)
# Out:
# c:\Users\srija\anaconda3\envs\aigc\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\srija\anaconda3\envs\aigc\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for param in model.parameters():
    param.requires_grad = True
for param in model.classifier.parameters():
           param.requires_grad = True

# %%
for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# features.conv0.weight True
# features.norm0.weight True
# features.norm0.bias True
# features.denseblock1.denselayer1.norm1.weight True
# features.denseblock1.denselayer1.norm1.bias True
# features.denseblock1.denselayer1.conv1.weight True
# features.denseblock1.denselayer1.norm2.weight True
# features.denseblock1.denselayer1.norm2.bias True
# features.denseblock1.denselayer1.conv2.weight True
# features.denseblock1.denselayer2.norm1.weight True
# features.denseblock1.denselayer2.norm1.bias True
# features.denseblock1.denselayer2.conv1.weight True
# features.denseblock1.denselayer2.norm2.weight True
# features.denseblock1.denselayer2.norm2.bias True
# features.denseblock1.denselayer2.conv2.weight True
# features.denseblock1.denselayer3.norm1.weight True
# features.denseblock1.denselayer3.norm1.bias True
# features.denseblock1.denselayer3.conv1.weight True
# features.denseblock1.denselayer3.norm2.weight True
# features.denseblock1.denselayer3.norm2.bias True
# ...

# %%
from torchsummary import summary

# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
densenet = densenet.to(device)
print(device)

 # Assuming input channels first

# Print the model summar
summary(densenet, (3,224,224))
# Out:
# cuda
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 11
#       6 print(device)
#       8  # Assuming input channels first
#       9
#      10 # Print the model summar
# ---> 11 summary(densenet, (3,224,224))
#
# File c:\Users\srija\anaconda3\envs\aigc\Lib\site-packages\torchsummary\torchsummary.py:72, in summary(model, input_size, batch_size, device)
#      68 model.apply(register_hook)
#      70 # make a forward pass
#      71 # print(x.shape)
# ---> 72 model(*x)
#      74 # remove these hooks
#      75 for h in hooks:
#
# File c:\Users\srija\anaconda3\envs\aigc\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# ...

# %%
# num_classes = len(train_dataset.classes)
# Change the last layer to fit the number of classes in your dataset
model.classifier = nn.Linear(1024, 7)
from tqdm import tqdm
from torch.optim.lr_scheduler import OneCycleLR
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model.load_state_dict(torch.load(r"C:\Users\srija\Assignment\AI_ML_GC\densenet_model_23.pth", map_location=torch.device('cuda')))  # Load the model

# Move model to device
model.to(device)

# Set model to training mode
model.train()

learning_rate = 0.0001

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
num_epochs = 10

# Training loop
for epoch in range(num_epochs):
    running_loss = 0.0
    correct = 0
    total = 0
    r_pre = 0

    # Wrap the dataloader with tqdm for progress bar
    for images, labels in tqdm(train_dataloader, desc=f'Epoch {epoch+1}/{num_epochs}'):
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)
        _, temp_labels = torch.max(labels, 1)
        
        outputs = model(images)
        prediction = outputs.max(1, keepdim=True)[1]
        # outputs =prediction


        # print(outputs)
    
        loss = criterion(outputs, temp_labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        
        total += labels.size(0)
        # print(total)
        
        # correct += (prediction == temp_labels).sum().item()
        r_pre += prediction.eq(temp_labels.view_as(prediction)).squeeze().sum()
        # print(r_pre)
    train_loss = running_loss / len(train_dataloader)
    train_accuracy = 100 * r_pre / total

    model.eval()  # Set the model to evaluation mode
    correct_val = 0
    total_val = 0
    val_running_loss = 0.0
    val_pre = 0

    with torch.no_grad():
        for images, labels in tqdm(val_dataloader, desc=f'Validation'):
            images = images.to(device)
            labels = labels.to(device)
            _, temp_labels = torch.max(labels, 1)
            outputs = model(images)
            prediction = outputs.max(1, keepdim=True)[1]
            # outputs =prediction
            
            val_loss = criterion(outputs, temp_labels)
            val_running_loss += val_loss.item()

            # _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            # correct_val += (prediction == temp_labels).sum().item()
            val_pre += prediction.eq(temp_labels.view_as(prediction)).squeeze().sum()

    # Calculate validation accuracy
    val_loss = val_running_loss / len(val_dataloader)
    val_accuracy = 100 * val_pre / total_val

    # Save model checkpoint
    torch.save(model.state_dict(), f'densenet_model_ver2_{epoch+1}.pth')

    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')

    # Set the model back to training mode
# Out:
# ...
# Validation: 100%|██████████| 460/460 [01:22<00:00,  5.58it/s]
# Epoch [1/10], Training Loss: 0.5222, Training Accuracy: 80.91%, Validation Loss: 0.2713, Validation Accuracy: 90.27%
# ...
# Validation: 100%|██████████| 460/460 [01:14<00:00,  6.16it/s]
# Epoch [2/10], Training Loss: 0.4402, Training Accuracy: 83.63%, Validation Loss: 0.2846, Validation Accuracy: 88.84%
# ...
# Validation: 100%|██████████| 460/460 [01:13<00:00,  6.23it/s]
# Epoch [3/10], Training Loss: 0.2647, Training Accuracy: 89.86%, Validation Loss: 0.2164, Validation Accuracy: 92.41%
# ...
# Validation: 100%|██████████| 460/460 [01:15<00:00,  6.09it/s]
# Epoch [4/10], Training Loss: 0.2069, Training Accuracy: 92.19%, Validation Loss: 0.1752, Validation Accuracy: 93.31%
# ...
# Validation: 100%|██████████| 460/460 [01:16<00:00,  5.98it/s]
# Epoch [5/10], Training Loss: 0.1749, Training Accuracy: 93.48%, Validation Loss: 0.1389, Validation Accuracy: 94.84%
# ...
# Validation: 100%|██████████| 460/460 [01:13<00:00,  6.23it/s]
# ...

# %%
model = ResNetModel(num_classes=num_classes)
model.load_state_dict(torch.load(r"C:\Users\srija\Downloads\resnet_model_vir2_1.pth", map_location=torch.device('cpu')))  # Load the model

# Set model to evaluation mode
model.eval()
# Out:
# ResNetModel(
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
device
# Out:
# device(type='cuda')

# %%
test_predictions = []
for i, images in enumerate(test_dataloader):
    with torch.no_grad():
        # images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        test_predictions.extend(predicted.tolist())
        print(i * 100 / len(test_dataloader))

# Create a DataFrame to store predictions
df_test = pd.DataFrame({'Prediction': test_predictions})
# Out:
# 0.0
# 0.13227513227513227
# 0.26455026455026454
# 0.3968253968253968
# 0.5291005291005291
# 0.6613756613756614
# 0.7936507936507936
# 0.9259259259259259
# 1.0582010582010581
# 1.1904761904761905
# 1.3227513227513228
# 1.4550264550264551
# 1.5873015873015872
# 1.7195767195767195
# 1.8518518518518519
# 1.9841269841269842
# 2.1164021164021163
# 2.248677248677249
# 2.380952380952381
# 2.513227513227513
# 2.6455026455026456
# 2.7777777777777777
# 2.9100529100529102
# 3.0423280423280423
# 3.1746031746031744
# 3.306878306878307
# 3.439153439153439
# 3.5714285714285716
# 3.7037037037037037
# 3.835978835978836
# 3.9682539682539684
# 4.1005291005291005
# 4.232804232804233
# 4.365079365079365
# 4.497354497354498
# 4.62962962962963
# 4.761904761904762
# 4.894179894179894
# 5.026455026455026
# 5.158730158730159
# 5.291005291005291
# 5.423280423280423
# 5.555555555555555
# 5.6878306878306875
# 5.8201058201058204
# 5.9523809523809526
# 6.084656084656085
# 6.216931216931217
# 6.349206349206349
# ...

# %%
df_sub = pd.DataFrame({'ID': list_test_id, 'Class': test_predictions})

# %%
df_sub.to_csv('final_predictions.csv', index=False)
